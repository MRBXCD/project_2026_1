# %%
! nvidia-smi
! git clone https://github.com/MRBXCD/project_2026_1.git
# Out:
# Thu Feb 12 23:02:02 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-80GB          Off |   00000000:00:05.0 Off |                    0 |
# | N/A   31C    P0             50W /  400W |       0MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
! cd ./project_2026_1

# %%
! ls
# Out:
# project_2026_1	sample_data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! cp /content/drive/MyDrive/A-Research/project_2026_1/data.zip ./proj_2026_1
! unzip ./proj_2026_1/data.zip -d ./proj_2026_1
# Out:
# unzip:  cannot find or open ./proj_2026_1/data.zip, ./proj_2026_1/data.zip.zip or ./proj_2026_1/data.zip.ZIP.

# %%
! ls -l /content/proj_2026_1
# Out:
# -rw------- 1 root root 307874423 Feb 12 23:05 /content/proj_2026_1

# %%
! python -m scripts.eval_sft --mode benchmark --benchmark_tasks mmlu,arc_challenge --num_fewshot 5 --sft_eval_mode peft
